# %%
from utils.tool_utils import *

# %%
a = '123'
print(a.split('_')[0])
print(a.isdigit())
# Out:
# 123
# True

# %%
metadata
# Out:
#      IXI_ID  SEX_ID (1=m, 2=f)  HEIGHT  WEIGHT  ETHNIC_ID  MARITAL_ID  \
# 0         1                  1     170      80          2           3
# 1         2                  2     164      58          1           4
# 2        12                  1     175      70          1           2
# 3        13                  1     182      70          1           2
# 4        14                  2     163      65          1           4
# ..      ...                ...     ...     ...        ...         ...
# 614     652                  1     163      80          1           1
# 615     653                  1     172     100          1           3
# 616     655                  1     165      72          1           1
# 617     660                  1     192      85          1           2
# 618     662                  1     182      98          1           4
#
#      OCCUPATION_ID  QUALIFICATION_ID                  DOB  DATE_AVAILABLE  \
# ...

# %%
path = '/home/DATABASE/IXI_tianmingxiao/IXI.xls'
metadata = load_meta_data(path)

# %%
metadata[metadata['IXI_ID']==228]
# Out:
# Empty DataFrame
# Columns: [IXI_ID, SEX_ID (1=m, 2=f), HEIGHT, WEIGHT, ETHNIC_ID, MARITAL_ID, OCCUPATION_ID, QUALIFICATION_ID, DOB, DATE_AVAILABLE, STUDY_DATE, AGE]
# Index: []

# %%
metadata.keys()
# Out:
# Index(['IXI_ID', 'SEX_ID (1=m, 2=f)', 'HEIGHT', 'WEIGHT', 'ETHNIC_ID',
#        'MARITAL_ID', 'OCCUPATION_ID', 'QUALIFICATION_ID', 'DOB',
#        'DATE_AVAILABLE', 'STUDY_DATE', 'AGE'],
#       dtype='object')

# %%
x = 2
a = 'm' if x == 1 else 'f'
a
# Out:
# 'f'
